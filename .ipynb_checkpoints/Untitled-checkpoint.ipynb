# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
ipl_data = pd.read_csv('IPL Matches 2008-2020.csv')

# %%
ipl_data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl_data.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
ipl_data['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Bengaluru', 'Dubai',
#        'Sharjah'], dtype=object)

# %%
ipl_data['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
ipl_data['team2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
ipl_data['result'].value_counts()
# Out:
# wickets    435
# runs       364
# tie         13
# Name: result, dtype: int64

# %%
a = ipl_data['date'].to_list()
year = []

# %%
for y in a:
    year.append(y[0:4])

# %%
ipl_data.insert(3,'Year',year)

# %%
ipl_data.drop(['date'],axis=1,inplace=True)

# %%
ipl_data
# Out:
#           id        city  Year player_of_match  \
# 0     335982   Bangalore  2008     BB McCullum
# 1     335983  Chandigarh  2008      MEK Hussey
# 2     335984       Delhi  2008     MF Maharoof
# 3     335985      Mumbai  2008      MV Boucher
# 4     335986     Kolkata  2008       DJ Hussey
# ..       ...         ...   ...             ...
# 811  1216547       Dubai  2020  AB de Villiers
# 812  1237177       Dubai  2020       JJ Bumrah
# 813  1237178   Abu Dhabi  2020   KS Williamson
# 814  1237180   Abu Dhabi  2020      MP Stoinis
# 815  1237181       Dubai  2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ...

# %%
ipl_data.shape
# Out:
# (816, 17)

# %%
ipl_macth_data = pd.read_csv('IPL Ball-by-Ball 2008-2020.csv')

# %%
ipl_macth_data
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
ipl_macth_data.shape
# Out:
# (193468, 18)

# %%
ipl_macth_data['batsman'].unique().shape
# Out:
# (537,)

# %%
win = ipl_data['winner'].value_counts()

# %%
win
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
win_count = ipl_data['winner'].value_counts().rename_axis('unique_values').reset_index(name='counts')

# %%
win_count
# Out:
#                   unique_values  counts
# 0                Mumbai Indians     120
# 1           Chennai Super Kings     106
# 2         Kolkata Knight Riders      99
# 3   Royal Challengers Bangalore      91
# 4               Kings XI Punjab      88
# 5              Rajasthan Royals      81
# 6              Delhi Daredevils      67
# 7           Sunrisers Hyderabad      66
# 8               Deccan Chargers      29
# 9                Delhi Capitals      19
# 10                Gujarat Lions      13
# 11                Pune Warriors      12
# 12       Rising Pune Supergiant      10
# 13         Kochi Tuskers Kerala       6
# 14      Rising Pune Supergiants       5

# %%
#winning of a team from 2008 to 2022
fig1, ax1 = plt.subplots()

ax1.pie(win_count['counts'], labels=win_count['unique_values'], autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.1090975494682942,
#  1.1042614955528567,
#  -1.106408275808595,
#  1.100305156089711)

# %%
total_runs_df = ipl_macth_data.groupby(['id','inning']).sum()['total_runs'].reset_index()

# %%
total_runs_df = total_runs_df[total_runs_df['inning'] == 1]

# %%
total_runs_df
# Out:
#            id  inning  total_runs
# 0      335982       1         222
# 2      335983       1         240
# 4      335984       1         129
# 6      335985       1         165
# 8      335986       1         110
# ...       ...     ...         ...
# 1620  1216547       1         201
# 1622  1237177       1         200
# 1624  1237178       1         131
# 1626  1237180       1         189
# 1628  1237181       1         156
#
# [816 rows x 3 columns]

# %%
ipl_df = ipl_data.merge(total_runs_df[['id','total_runs']],left_on='id',right_on='id')

# %%
ipl_df
# Out:
#           id        city  Year player_of_match  \
# 0     335982   Bangalore  2008     BB McCullum
# 1     335983  Chandigarh  2008      MEK Hussey
# 2     335984       Delhi  2008     MF Maharoof
# 3     335985      Mumbai  2008      MV Boucher
# 4     335986     Kolkata  2008       DJ Hussey
# ..       ...         ...   ...             ...
# 811  1216547       Dubai  2020  AB de Villiers
# 812  1237177       Dubai  2020       JJ Bumrah
# 813  1237178   Abu Dhabi  2020   KS Williamson
# 814  1237180   Abu Dhabi  2020      MP Stoinis
# 815  1237181       Dubai  2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ...

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
]

# %%
ipl_df['team1'] =ipl_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
ipl_df['team2'] =ipl_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

ipl_df['team1'] = ipl_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
ipl_df['team2'] = ipl_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
ipl_df = ipl_df[ipl_df['team1'].isin(teams)]
ipl_df = ipl_df[ipl_df['team2'].isin(teams)]

# %%
ipl_df.shape
# Out:
# (701, 18)

# %%
ipl_df = ipl_df[['id','city','winner','total_runs']]

# %%
ipl_df_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7500\4240163135.py in <module>
# ----> 1 ipl_df_
#
# NameError: name 'ipl_df_' is not defined

# %%
ipl_df = ipl_macth_data.merge(ipl_df,on='id')

# %%
macth_data_df = ipl_df[ipl_df['inning']==2]

# %%
macth_data_df
# Out:
#              id  inning  over  ball       batsman   non_striker      bowler  \
# 121      335982       2     6     2      CL White    MV Boucher  AB Agarkar
# 122      335982       2     6     3      CL White    MV Boucher  AB Agarkar
# 123      335982       2     6     4    MV Boucher      CL White  AB Agarkar
# 124      335982       2     6     5    MV Boucher      CL White  AB Agarkar
# 125      335982       2     6     6    MV Boucher      CL White  AB Agarkar
# ...         ...     ...   ...   ...           ...           ...         ...
# 166366  1237181       2    17     6     HH Pandya  Ishan Kishan    K Rabada
# 166367  1237181       2    18     1     HH Pandya  Ishan Kishan    A Nortje
# 166368  1237181       2    18     2  Ishan Kishan     HH Pandya    A Nortje
# 166369  1237181       2    18     3     HH Pandya  Ishan Kishan    A Nortje
# 166370  1237181       2    18     4     KH Pandya  Ishan Kishan    A Nortje
#
# ...

# %%
macth_data_df['current_score'] = macth_data_df.groupby(['id']).cumsum()['total_runs_x']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7500\788400317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   macth_data_df['current_score'] = macth_data_df.groupby(['id']).cumsum()['total_runs_x']

# %%
macth_data_df
# Out:
#              id  inning  over  ball       batsman   non_striker      bowler  \
# 121      335982       2     6     2      CL White    MV Boucher  AB Agarkar
# 122      335982       2     6     3      CL White    MV Boucher  AB Agarkar
# 123      335982       2     6     4    MV Boucher      CL White  AB Agarkar
# 124      335982       2     6     5    MV Boucher      CL White  AB Agarkar
# 125      335982       2     6     6    MV Boucher      CL White  AB Agarkar
# ...         ...     ...   ...   ...           ...           ...         ...
# 166366  1237181       2    17     6     HH Pandya  Ishan Kishan    K Rabada
# 166367  1237181       2    18     1     HH Pandya  Ishan Kishan    A Nortje
# 166368  1237181       2    18     2  Ishan Kishan     HH Pandya    A Nortje
# 166369  1237181       2    18     3     HH Pandya  Ishan Kishan    A Nortje
# 166370  1237181       2    18     4     KH Pandya  Ishan Kishan    A Nortje
#
# ...

# %%
macth_data_df['runs left'] = macth_data_df['total_runs_y'] - macth_data_df['current_score']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7500\1088206784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   macth_data_df['runs left'] = macth_data_df['total_runs_y'] - macth_data_df['current_score']

# %%
macth_data_df.head()
# Out:
#          id  inning  over  ball     batsman non_striker      bowler  \
# 121  335982       2     6     2    CL White  MV Boucher  AB Agarkar
# 122  335982       2     6     3    CL White  MV Boucher  AB Agarkar
# 123  335982       2     6     4  MV Boucher    CL White  AB Agarkar
# 124  335982       2     6     5  MV Boucher    CL White  AB Agarkar
# 125  335982       2     6     6  MV Boucher    CL White  AB Agarkar
#
#      batsman_runs  extra_runs  total_runs_x  ...  player_dismissed  fielder  \
# 121             0           0             0  ...               NaN      NaN
# 122             1           0             1  ...               NaN      NaN
# 123             0           1             1  ...               NaN      NaN
# 124             0           1             1  ...               NaN      NaN
# 125             0           0             0  ...               NaN      NaN
#
#     extras_type                 batting_team           bowling_team  \
# ...

# %%
macth_data_df['balls left'] = 126 - (macth_data_df['over']*6 + macth_data_df['ball'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7500\3828757883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   macth_data_df['balls left'] = 126 - (macth_data_df['over']*6 + macth_data_df['ball'])

# %%
macth_data_df
# Out:
#              id  inning  over  ball       batsman   non_striker      bowler  \
# 121      335982       2     6     2      CL White    MV Boucher  AB Agarkar
# 122      335982       2     6     3      CL White    MV Boucher  AB Agarkar
# 123      335982       2     6     4    MV Boucher      CL White  AB Agarkar
# 124      335982       2     6     5    MV Boucher      CL White  AB Agarkar
# 125      335982       2     6     6    MV Boucher      CL White  AB Agarkar
# ...         ...     ...   ...   ...           ...           ...         ...
# 166366  1237181       2    17     6     HH Pandya  Ishan Kishan    K Rabada
# 166367  1237181       2    18     1     HH Pandya  Ishan Kishan    A Nortje
# 166368  1237181       2    18     2  Ishan Kishan     HH Pandya    A Nortje
# 166369  1237181       2    18     3     HH Pandya  Ishan Kishan    A Nortje
# 166370  1237181       2    18     4     KH Pandya  Ishan Kishan    A Nortje
#
# ...

# %%
macth_data_df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs_x', 'non_boundary',
#        'is_wicket', 'dismissal_kind', 'player_dismissed', 'fielder',
#        'extras_type', 'batting_team', 'bowling_team', 'city', 'winner',
#        'total_runs_y', 'current_score', 'runs left', 'balls left'],
#       dtype='object')

# %%
macth_data_df['player_dismissed'] = macth_data_df['player_dismissed'].fillna('0')
macth_data_df['player_dismissed'] = macth_data_df['player_dismissed'].apply(lambda x:x if x=='0' else '1')
#wickets = macth_data_df.groupby('id').cumsum()['player_dismissed'].values()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7500\2165542745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   macth_data_df['player_dismissed'] = macth_data_df['player_dismissed'].fillna('0')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7500\2165542745.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   macth_data_df['player_dismissed'] = macth_data_df['player_dismissed'].apply(lambda x:x if x=='0' else '1')

# %%
wickets = macth_data_df.groupby('id').cumsum()['player_dismissed']
wickets
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'player_dismissed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
macth_data_df['player_dismissed']
# Out:
# 121       0
# 122       0
# 123       0
# 124       0
# 125       0
#          ..
# 166366    0
# 166367    0
# 166368    0
# 166369    1
# 166370    0
# Name: player_dismissed, Length: 80341, dtype: object

# %%
macth_data_df['wickets left'] = 10 - wickets
macth_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7500\3834157201.py in <module>
# ----> 1 macth_data_df['wickets left'] = 10 - wickets
#       2 macth_data_df.head()
#
# NameError: name 'wickets' is not defined
